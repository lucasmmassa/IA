# %% [markdown]
# # Rede neural para classificar se uma pessoa possui doença cardíaca
# Foi utilizado este dataset https://archive.ics.uci.edu/ml/datasets/Heart+Disease

# %%
# Importing libs
import pandas as pd
import numpy as np
import keras
from keras.metrics import *
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import *
import matplotlib.pyplot as plt

# %%
# Reading data from csv
data = pd.read_csv('heart.csv')
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0     63    1   3       145   233    1  ...      0      2.3      0   0     1       1
# 1     37    1   2       130   250    0  ...      0      3.5      0   0     2       1
# 2     41    0   1       130   204    0  ...      0      1.4      2   0     2       1
# 3     56    1   1       120   236    0  ...      0      0.8      2   0     2       1
# 4     57    0   0       120   354    0  ...      1      0.6      2   0     2       1
# ..   ...  ...  ..       ...   ...  ...  ...    ...      ...    ...  ..   ...     ...
# 298   57    0   0       140   241    0  ...      1      0.2      1   0     3       0
# 299   45    1   3       110   264    0  ...      0      1.2      1   0     3       0
# 300   68    1   0       144   193    1  ...      0      3.4      1   2     3       0
# 301   57    1   0       130   131    0  ...      1      1.2      1   1     3       0
# 302   57    0   1       130   236    0  ...      0      0.0      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Dividindo os dados entre treino e teste

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data.iloc[:,0:13], data.iloc[:,13], test_size = 0.2, shuffle = True, stratify = data['target'])

# %%
x_train
# Out:
#      age  sex  cp  trestbps  chol  ...  exang  oldpeak  slope  ca  thal
# 262   53    1   0       123   282  ...      1      2.0      1   2     3
# 125   34    0   1       118   210  ...      0      0.7      2   0     2
# 126   47    1   0       112   204  ...      0      0.1      2   0     2
# 120   64    0   0       130   303  ...      0      2.0      1   2     2
# 116   41    1   2       130   214  ...      0      2.0      1   0     2
# ..   ...  ...  ..       ...   ...  ...    ...      ...    ...  ..   ...
# 271   61    1   3       134   234  ...      0      2.6      1   2     2
# 29    53    1   2       130   197  ...      0      1.2      0   0     2
# 150   66    1   0       160   228  ...      0      2.3      2   0     1
# 191   58    1   0       128   216  ...      1      2.2      1   3     3
# 46    44    1   2       140   235  ...      0      0.0      2   0     2
#
# [242 rows x 13 columns]

# %%
y_train
# Out:
# 262    0
# 125    1
# 126    1
# 120    1
# 116    1
#       ..
# 271    0
# 29     1
# 150    1
# 191    0
# 46     1
# Name: target, Length: 242, dtype: int64

# %%
x_test
# Out:
#      age  sex  cp  trestbps  chol  ...  exang  oldpeak  slope  ca  thal
# 122   41    0   2       112   268  ...      1      0.0      2   0     2
# 173   58    1   2       132   224  ...      0      3.2      2   2     3
# 170   56    1   2       130   256  ...      1      0.6      1   1     1
# 258   62    0   0       150   244  ...      1      1.4      1   0     2
# 10    54    1   0       140   239  ...      0      1.2      2   0     2
# ..   ...  ...  ..       ...   ...  ...    ...      ...    ...  ..   ...
# 209   59    1   0       140   177  ...      1      0.0      2   1     3
# 66    51    1   2       100   222  ...      1      1.2      1   0     2
# 11    48    0   2       130   275  ...      0      0.2      2   0     2
# 297   59    1   0       164   176  ...      0      1.0      1   2     1
# 27    51    1   2       110   175  ...      0      0.6      2   0     2
#
# [61 rows x 13 columns]

# %%
y_test
# Out:
# 122    1
# 173    0
# 170    0
# 258    0
# 10     1
#       ..
# 209    0
# 66     1
# 11     1
# 297    0
# 27     1
# Name: target, Length: 61, dtype: int64

# %% [markdown]
# ## Preparando os dados para serem usados
# Normalização das colunas

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
train = x_train.iloc[:,:].values.astype(float)

# %%
test = x_test.iloc[:,:].values.astype(float)

# %%
train_scaled = scaler.fit_transform(train)
test_scaled = scaler.fit_transform(test)

# %%
x_train_normalized = pd.DataFrame(train_scaled,columns=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach','exang', 'oldpeak', 'slope', 'ca', 'thal'])
x_test_normalized = pd.DataFrame(test_scaled,columns=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach','exang', 'oldpeak', 'slope', 'ca', 'thal'])

# %%
x_train_normalized
# Out:
#           age  sex        cp  trestbps  ...   oldpeak  slope    ca      thal
# 0    0.500000  1.0  0.000000  0.273585  ...  0.322581    0.5  0.50  1.000000
# 1    0.104167  0.0  0.333333  0.226415  ...  0.112903    1.0  0.00  0.666667
# 2    0.375000  1.0  0.000000  0.169811  ...  0.016129    1.0  0.00  0.666667
# 3    0.729167  0.0  0.000000  0.339623  ...  0.322581    0.5  0.50  0.666667
# 4    0.250000  1.0  0.666667  0.339623  ...  0.322581    0.5  0.00  0.666667
# ..        ...  ...       ...       ...  ...       ...    ...   ...       ...
# 237  0.666667  1.0  1.000000  0.377358  ...  0.419355    0.5  0.50  0.666667
# 238  0.500000  1.0  0.666667  0.339623  ...  0.193548    0.0  0.00  0.666667
# 239  0.770833  1.0  0.000000  0.622642  ...  0.370968    1.0  0.00  0.333333
# 240  0.604167  1.0  0.000000  0.320755  ...  0.354839    0.5  0.75  1.000000
# 241  0.312500  1.0  0.666667  0.433962  ...  0.000000    1.0  0.00  0.666667
#
# [242 rows x 13 columns]

# %%
x_test_normalized
# Out:
#          age  sex        cp  trestbps  ...   oldpeak  slope    ca      thal
# 0   0.181818  0.0  0.666667  0.209302  ...  0.000000    1.0  0.00  0.666667
# 1   0.696970  1.0  0.666667  0.441860  ...  0.571429    1.0  0.50  1.000000
# 2   0.636364  1.0  0.666667  0.418605  ...  0.107143    0.5  0.25  0.333333
# 3   0.818182  0.0  0.000000  0.651163  ...  0.250000    0.5  0.00  0.666667
# 4   0.575758  1.0  0.000000  0.534884  ...  0.214286    1.0  0.00  0.666667
# ..       ...  ...       ...       ...  ...       ...    ...   ...       ...
# 56  0.727273  1.0  0.000000  0.534884  ...  0.000000    1.0  0.25  1.000000
# 57  0.484848  1.0  0.666667  0.069767  ...  0.214286    0.5  0.00  0.666667
# 58  0.393939  0.0  0.666667  0.418605  ...  0.035714    1.0  0.00  0.666667
# 59  0.727273  1.0  0.000000  0.813953  ...  0.178571    0.5  0.50  0.333333
# 60  0.484848  1.0  0.666667  0.186047  ...  0.107143    1.0  0.00  0.666667
#
# [61 rows x 13 columns]

# %% [markdown]
# ## Criando o modelo

# %%
model1 = Sequential()

# %%
model1.add(Dense(30, activation='relu', input_shape=(13,)))
model1.add(Dropout(0.75))
model1.add(Dense(1, activation='sigmoid'))

# %%
model1.compile(loss='binary_crossentropy',optimizer=Adam(learning_rate = 0.01),
               metrics=['accuracy'])

# %% [markdown]
# ## Treinando o modelo
# Usou-se batch gradient descent junto com early stopping

# %%
batch_size = 242
epochs = 100
history = model1.fit(
    x_train_normalized, y_train,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(x_test_normalized, y_test),
    shuffle = True,
    callbacks=[keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=20,min_delta=0.01)])
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/100
# 242/242 [==============================] - 1s 3ms/step - loss: 0.7742 - accuracy: 0.4463 - val_loss: 0.7421 - val_accuracy: 0.3279
# Epoch 2/100
# 242/242 [==============================] - 0s 32us/step - loss: 0.7252 - accuracy: 0.5165 - val_loss: 0.7227 - val_accuracy: 0.4098
# Epoch 3/100
# 242/242 [==============================] - 0s 61us/step - loss: 0.6859 - accuracy: 0.5620 - val_loss: 0.7039 - val_accuracy: 0.5082
# Epoch 4/100
# 242/242 [==============================] - 0s 45us/step - loss: 0.6976 - accuracy: 0.5455 - val_loss: 0.6867 - val_accuracy: 0.5902
